# %% [markdown]
# <a href="https://colab.research.google.com/github/Ximearex/AI/blob/main/Assignments/AF3_Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment 4.- Supervised learning model: Decision tree.**
#
# ---
#
#
#
# 2132194 - Jorge Alfonso Garcia Rodriguez
#
# 2109522 - Camila Andrea Silva Espinoza
#
# 2055629 - Ximena Arellano Arellano
#
# 1929944 - Alejandra Janeth Hernandez Grimaldo
#
# Class N4-N6
#
#
# ---

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6cde4bde-f1c0-431c-ad7c-72d45805df38" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6cde4bde-f1c0-431c-ad7c-72d45805df38">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
X = df.drop('diagnosis', axis=1)
y = df['diagnosis']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

# %%
model = DecisionTreeClassifier(random_state=25)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=25)

# %%
predictions = model.predict(X_test[:3])
print("Predictions:", predictions)
print("Real Values:", y_test[:3].values)
# Out:
# Predictions: ['B' 'B' 'B']
# Real Values: ['B' 'B' 'B']

# %%
y_pred = model.predict(X_test)
print("Model Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification report:\n", classification_report(y_test, y_pred))
# Out:
# Model Accuracy: 0.9298245614035088
#
# Classification report:
#                precision    recall  f1-score   support
#
#            B       0.92      0.97      0.95        75
#            M       0.94      0.85      0.89        39
#
#     accuracy                           0.93       114
#    macro avg       0.93      0.91      0.92       114
# weighted avg       0.93      0.93      0.93       114

# %%
plt.figure(figsize=(20,10), dpi=300)
plot_tree(model, feature_names=X.columns, class_names=["malignant", "benign"], filled=True)
plt.show()

# %% [markdown]
# # References:
#
# ---
#
#
#
# Matthes, E. (2023). Python crash course. No starch press.
#
# https://www.w3schools.com/python/default.asp
#
# Géron, A. (2022). Hands-on machine learning with Scikit-Learn, Keras, and TensorFlow. " O'Reilly Media, Inc.".
